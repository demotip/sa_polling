# %%
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
bursts = pd.read_csv('./pcm/pcm_campaign.csv')

# %%
bursts
# Out:
#                                        PLEASE CALL ME  Date  Total Cost  CPM  \
# 0                                                 NaN   NaN         NaN  NaN
# 1   PCM Broadcast Media -1 User pays std rates (20...   8.0     80000.0  6.0
# 2        PCM Broadcast Media -2 User pays + Incentive   9.0     80000.0  6.0
# 3          PCM Broadcast Media -3 Zero-rated (we pay)  10.0     80000.0  6.0
# 4                                                 NaN   NaN         NaN  NaN
# 5   PCM Broadcast Media -1 User pays std rates (20...  19.0      6000.0  6.0
# 6        PCM Broadcast Media -2 User pays + Incentive  20.0      6000.0  6.0
# 7          PCM Broadcast Media -3 Zero-rated (we pay)  21.0      6000.0  6.0
# 8                                                 NaN   NaN         NaN  NaN
# 9   PCM Broadcast Media -1 User pays std rates (20...  24.0      6000.0  6.0
# 10       PCM Broadcast Media -2 User pays + Incentive  25.0      6000.0  6.0
# 11         PCM Broadcast Media -3 Zero-rated (we pay)  26.0      6000.0  6.0
# 12                                                NaN   NaN         NaN  NaN
# 13  PCM Broadcast Media -1 User pays std rates (20...  28.0      6000.0  6.0
# 14       PCM Broadcast Media -2 User pays + Incentive  29.0      6000.0  6.0
# 15         PCM Broadcast Media -3 Zero-rated (we pay)  30.0      6000.0  6.0
#
#     Total Impressions
# 0                 NaN
# 1          13333333.0
# 2          13333333.0
# 3          13333333.0
# 4                 NaN
# 5           1000000.0
# 6           1000000.0
# 7           1000000.0
# 8                 NaN
# 9           1000000.0
# 10          1000000.0
# 11          1000000.0
# 12                NaN
# 13          1000000.0
# 14          1000000.0
# 15          1000000.0

# %%
df2 = pd.read_csv("./bursts.csv")
df2 = df2.set_index('date')

# %%
df2
# Out:
#             total  control  lottery  subsidy
# date
# 2014-03-01    0.0      0.0      0.0      0.0
# 2014-03-02    0.0      0.0      0.0      0.0
# 2014-03-03    0.0      0.0      0.0      0.0
# 2014-03-04    0.0      0.0      0.0      0.0
# 2014-03-05   19.0      0.0      0.0      0.0
# 2014-03-06    0.0      0.0      0.0      0.0
# 2014-03-07    0.0      0.0      0.0      0.0
# 2014-03-08    0.0      0.0      0.0      0.0
# 2014-03-09    0.0      0.0      0.0      0.0
# 2014-03-10    7.0      0.0      0.0      0.0
# 2014-03-11   33.0      0.0      0.0      0.0
# 2014-03-12    0.0      0.0      0.0      0.0
# 2014-03-13   81.0      0.0      0.0      0.0
# 2014-03-14   93.0      0.0      0.0      0.0
# 2014-03-15   54.0      0.0      0.0      0.0
# 2014-03-16    0.0      0.0      0.0      0.0
# 2014-03-17  135.0      0.0      0.0      0.0
# 2014-03-18  162.0      0.0      0.0      0.0
# 2014-03-19  184.0      0.0      0.0      0.0
# 2014-03-20  109.0      0.0      0.0      0.0
# 2014-03-21   46.0      0.0      0.0      0.0
# 2014-03-22    0.0      0.0      0.0      0.0
# 2014-03-23    0.0      0.0      0.0      0.0
# 2014-03-24    0.0      0.0      0.0      0.0
# 2014-03-25  185.0      0.0      0.0      0.0
# 2014-03-26    0.0      0.0      0.0      0.0
# 2014-03-27    0.0      0.0      0.0      0.0
# 2014-03-28   74.0      0.0      0.0      0.0
# 2014-03-29  924.0      0.0      0.0      0.0
# 2014-03-30    0.0      0.0      0.0      0.0
# ...           ...      ...      ...      ...
# 2014-08-01  139.0     12.0     34.0      0.0
# 2014-08-02  112.0      0.0     13.0      0.0
# 2014-08-03  240.0     21.0     57.0      0.0
# 2014-08-04  103.0      6.0     10.0      0.0
# 2014-08-05  177.0      8.0     69.0      0.0
# 2014-08-06  112.0      0.0     24.0      0.0
# 2014-08-07   94.0     12.0      9.0      0.0
# 2014-08-08  112.0     11.0     26.0      0.0
# 2014-08-09  156.0      3.0     34.0      0.0
# 2014-08-10   97.0     12.0     33.0      0.0
# 2014-08-11  125.0      2.0     28.0      0.0
# 2014-08-12   79.0     10.0      6.0      0.0
# 2014-08-13   97.0      9.0      4.0      0.0
# 2014-08-14   79.0      0.0     11.0      0.0
# 2014-08-15  111.0      6.0      7.0      0.0
# 2014-08-16  199.0     13.0     80.0      0.0
# 2014-08-17  135.0      7.0     17.0      0.0
# 2014-08-18  117.0      5.0     24.0      0.0
# 2014-08-19   98.0      6.0      6.0      0.0
# 2014-08-20  177.0     10.0      5.0      0.0
# 2014-08-21  177.0      3.0     71.0      0.0
# 2014-08-22  141.0      0.0     16.0      0.0
# 2014-08-23   99.0      7.0     23.0      0.0
# 2014-08-24  122.0      1.0     12.0      0.0
# 2014-08-25  113.0      5.0     11.0      0.0
# 2014-08-26   81.0      2.0     10.0      0.0
# 2014-08-27   73.0     13.0      3.0      0.0
# 2014-08-28  105.0      5.0      3.0      0.0
# 2014-08-29  119.0      3.0     34.0      0.0
# 2014-08-30  124.0      0.0     24.0      0.0
#
# [183 rows x 4 columns]

# %%
df2.index.min()
# Out:
# '2014-03-01'

# %%
df2.index.max()
# Out:
# '2014-08-30'

# %%
df2.index = pd.to_datetime(df2.index)
range_1 = 35
range_2 = -112
# plt.plot(df2.index[range_1:range_2], df2['total'].iloc[range_1:range_2])
fig, ax = plt.subplots()
ax.plot(df2.index[range_1:range_2], df2['control'].iloc[range_1:range_2], label='lottery')
ax.plot(df2.index[range_1:range_2], df2['lottery'].iloc[range_1:range_2], label='control')
ax.plot(df2.index[range_1:range_2], df2['subsidy'].iloc[range_1:range_2], label='subsidy')

ax.set_ylabel('# responses')
ax.set_title('Number of Reponses')
# xticks = df2.index[range_1:range_2:2]
plt.xticks(rotation=45, fontsize=8)
ax.tick_params(axis='y',which='minor',bottom='on')
plt.yticks(pd.np.arange(0, 9e4, 1e4), ('0', '10k', '20k', '30k', '40k', '50k', '60k', '70k', '80k') )
plt.legend(loc=1)
plt.grid()
plt.savefig('./my_fig.png', dpi=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.index[range_1:range_2].strftime('%m-%d').tolist()
